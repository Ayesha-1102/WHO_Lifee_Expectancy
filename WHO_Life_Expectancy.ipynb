# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-1102/WHO_Lifee_Expectancy/blob/main/WHO_Life_Expectancy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Using Random Forest Algorithm
# prediction on  WHO Life Expectancy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5babf025-bfce-427c-8cd4-1cf01e942d35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5babf025-bfce-427c-8cd4-1cf01e942d35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Replace 'Life_Expectancy_Data.xlsx' with the actual file path if it's local
file_path = './Life_Expectancy_Data.xlsx'

# Load the Excel file
data = pd.read_excel(file_path)

# Preview the data
print(data.head())
# Out:
#        Country    Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015.0  Developing            263.0           62.0     0.01
# 1  Afghanistan  2014.0  Developing            271.0           64.0     0.01
# 2  Afghanistan  2013.0  Developing            268.0           66.0     0.01
# 3  Afghanistan  2012.0  Developing            272.0           69.0     0.01
# 4  Afghanistan  2011.0  Developing            275.0           71.0     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0    1154.0   19.1  ...
# 1               73.523582         62.0     492.0   18.6  ...
# 2               73.219243         64.0     430.0   18.1  ...
# 3               78.184215         67.0    2787.0   17.6  ...
# 4                7.097109         68.0    3013.0   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Country=LabelEncoder()
Status=LabelEncoder()
data['Country']=Country.fit_transform(data['Country'])
data['Status']=Country.fit_transform(data['Status'])
data.tail()
# Out:
#       Country    Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 2933      192  2004.0       1            723.0           27.0     4.36
# 2934      192  2003.0       1            715.0           26.0     4.06
# 2935      192  2002.0       1             73.0           25.0     4.43
# 2936      192  2001.0       1            686.0           25.0     1.72
# 2937      192  2000.0       1            665.0           24.0     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 2933                     0.0         68.0      31.0   27.1  ...
# 2934                     0.0          7.0     998.0   26.7  ...
# 2935                     0.0         73.0     304.0   26.3  ...
# 2936                     0.0         76.0     529.0   25.9  ...
# 2937                     0.0         79.0    1483.0   25.5  ...
#
#       Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 2933               7.13         65.0       33.6  454.366654  12777511.0
# ...

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# Create the SimpleImputer instance
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# Use it on your data
X = imputer.fit_transform(data)

# %%
data.shape
# Out:
# (2938, 22)

# %%
X=data.iloc[:,:21]
y=data.iloc[:,-1]

# %%
y.head()
X.head()
# Out:
#    Country    Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 0        0  2015.0       1            263.0           62.0     0.01
# 1        0  2014.0       1            271.0           64.0     0.01
# 2        0  2013.0       1            268.0           66.0     0.01
# 3        0  2012.0       1            272.0           69.0     0.01
# 4        0  2011.0       1            275.0           71.0     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0               71.279624         65.0    1154.0   19.1  ...    6.0
# 1               73.523582         62.0     492.0   18.6  ...   58.0
# 2               73.219243         64.0     430.0   18.1  ...   62.0
# 3               78.184215         67.0    2787.0   17.6  ...   67.0
# 4                7.097109         68.0    3013.0   17.2  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_test
# Out:
#       Country    Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 867        56  2014.0       1            122.0            0.0     0.01
# 1780      115  2015.0       1            199.0           39.0      NaN
# 621        37  2002.0       1            424.0            9.0     2.55
# 2715      179  2014.0       1             38.0           68.0     0.01
# 2717      179  2012.0       1            339.0           73.0     0.01
# ...       ...     ...     ...              ...            ...      ...
# 1290       82  2007.0       0             63.0            2.0     8.37
# 2724      179  2005.0       1            446.0           99.0    10.09
# 392        24  2007.0       0            157.0            1.0    10.89
# 27          1  2004.0       1             17.0            1.0     4.54
# 674        42  2014.0       0             53.0            0.0     0.01
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# ...

# %%
X_train
# Out:
#       Country    Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 683        42  2005.0       0             65.0            0.0    11.41
# 478        28  2001.0       1            273.0           25.0     1.71
# 2359      155  2001.0       0            124.0            0.0    10.80
# 971        62  2006.0       1            288.0            3.0     2.93
# 880        56  2001.0       1            225.0            0.0     0.01
# ...       ...     ...     ...              ...            ...      ...
# 763        48  2005.0       1            318.0            2.0     1.23
# 835        54  2014.0       1             32.0            3.0     0.01
# 1653      106  2013.0       1             28.0            8.0     0.01
# 2607      171  2009.0       1            165.0            2.0     0.09
# 2732      180  2013.0       1            198.0            4.0     8.44
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# ...

# %%
y_train
# Out:
# 683     78.7
# 478     58.5
# 2359    76.2
# 971     58.2
# 880     78.0
#         ...
# 763     58.6
# 835     57.9
# 1653    62.7
# 2607    66.6
# 2732    71.0
# Name: Life expectancy , Length: 2350, dtype: float64

# %%
y_test
# Out:
# 867     77.3
# 1780    66.6
# 621     52.6
# 2715    61.5
# 2717    60.0
#         ...
# 1290    81.3
# 2724    53.2
# 392     72.6
# 27      73.0
# 674     83.0
# Name: Life expectancy , Length: 588, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import mean_squared_error

# %%
Reg = RandomForestRegressor(n_estimators=100, criterion='mse')

# %%
reg = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=100, n_features=1, noise=0.1, random_state=42)
reg = RandomForestRegressor(n_estimators=100, random_state=42)
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
Prediction=reg.predict(X_test)
print(Prediction)
# Out:
# [-57.92392265  61.9851536   34.36369977 -15.72942071  -9.805372
#  -12.5852113  -19.54058728 -75.32970111  34.36369977  38.98493755
#   43.17846207  15.01687273 -48.97069799 -21.9443876  -46.91156334
#  -19.60250155  40.77500962  10.25320262  31.98180581  14.9543574 ]

# %%
Prediction=reg.predict(X_test)
print(Prediction[:5])
# Out:
# [-57.92392265  61.9851536   34.36369977 -15.72942071  -9.805372  ]

# %%
reg.score(X_test,y_test)
# Out:
# 0.9993636078552096

# %%
plt.scatter(X,y)

# %%
plt.figure(figsize=(10,5))

# %%
plt.show()

# %%
plt.plot(X_test,Prediction)

# %%
reg.score(X_test,y_test)
# Out:
# 0.9993636078552096

# %%
from google.colab import drive
drive.mount('/content/drive')
